# %% [markdown]
# ### Задание 1. Загрузка данных
# Изучить представленный набор данных на основе описания его столбцов, загрузить его и оставить 8 столбцов для дальнейшего изучения: surgery?, Age, rectal temperature, pulse, respiratory rate, temperature of extremities, pain, outcome.

# %%
f = open('horse_data.names', 'r', encoding = 'utf8')

# %%
many =f.readlines()

# %%
info = many[29:264]
info
# Out:
# ['  1:  surgery?\n',
#  '          1 = Yes, it had surgery\n',
#  '          2 = It was treated without surgery\n',
#  '\n',
#  '  2:  Age\n',
#  '          1 = Adult horse\n',
#  '          2 = Young (< 6 months)\n',
#  '\n',
#  '  3:  Hospital Number\n',
#  '          - numeric id\n',
#  '          - the case number assigned to the horse\n',
#  '            (may not be unique if the horse is treated > 1 time)\n',
#  '\n',
#  '  4:  rectal temperature\n',
#  '          - linear\n',
#  '          - in degrees celsius.\n',
#  '          - An elevated temp may occur due to infection.\n',
#  '          - temperature may be reduced when the animal is in late shock\n',
#  '          - normal temp is 37.8\n',
#  '          - this parameter will usually change as the problem progresses\n',
#  '               eg. may start out normal, then become elevated because of\n',
#  '                   the lesion, passing back through the normal range as the\n',
# ...

# %% [markdown]
# ### КОММЕНТ
# Здесь в верхней части оставил нужную инфо в переменной info,
# ниже я перевел в json строки чтобы скопировать нужные названия колонок через REGEX

# %%
import json
y = json.dumps(info)
y
# Out:
# '["  1:  surgery?\\n", "          1 = Yes, it had surgery\\n", "          2 = It was treated without surgery\\n", "\\n", "  2:  Age\\n", "          1 = Adult horse\\n", "          2 = Young (< 6 months)\\n", "\\n", "  3:  Hospital Number\\n", "          - numeric id\\n", "          - the case number assigned to the horse\\n", "            (may not be unique if the horse is treated > 1 time)\\n", "\\n", "  4:  rectal temperature\\n", "          - linear\\n", "          - in degrees celsius.\\n", "          - An elevated temp may occur due to infection.\\n", "          - temperature may be reduced when the animal is in late shock\\n", "          - normal temp is 37.8\\n", "          - this parameter will usually change as the problem progresses\\n", "               eg. may start out normal, then become elevated because of\\n", "                   the lesion, passing back through the normal range as the\\n", "                   horse goes into shock\\n", "  5:  pulse\\n", "          - l
# ...

# %%
import re
find_columns = re.findall(r'\d{1,2}\:\s+\w+', y)
print(find_columns)
# Out:
# ['1:  surgery', '2:  Age', '3:  Hospital', '4:  rectal', '5:  pulse', '6:  respiratory', '7:  temperature', '8:  peripheral', '9:  mucous', '10: capillary', '11: pain', '12: peristalsis', '13: abdominal', '14: nasogastric', '15: nasogastric', '16: nasogastric', '17: rectal', '18: abdomen', '19: packed', '20: total', '21: abdominocentesis', '22: abdomcentesis', '23: outcome', '24: surgical', '27: type', '28: cp_data']

# %%
import pandas as pd

# %%
horse_data = pd.read_csv('horse_data.csv')

# %%
horse_data = pd.DataFrame(horse_data)

# %%
horse_data.columns =['surgery?', 'age', 'Hospital Number', 'rectal temperature', 'pulse', 'respiratory rate', 'temperature of extremities'
                    , 'peripheral pulse', 'mucous membranes', 'capillary refill time', 'pain', 'peristalsis','abdominal distension',
                    'nasogastric tube', 'nasogastric reflux', 'nasogastric reflux PH', 'rectal examination - feces', 'abdomen',
                     'packed cell volume', 'total protein', 'abdominocentesis appearance', 'abdomcentesis total protein', 'outcome',
                     'surgical lesion', 'type of lesion', 'type of lesion', 'type of lesion', 'cp_data' 
                    ]

# %%
horse_data = horse_data.replace(to_replace='?', value='NaN')
horse_data
# Out:
#     surgery?  age  Hospital Number rectal temperature pulse respiratory rate  \
# 0          1    1           534817               39.2    88               20
# 1          2    1           530334              38.30    40               24
# 2          1    9          5290409              39.10   164               84
# 3          2    1           530255              37.30   104               35
# 4          2    1           528355                NaN   NaN              NaN
# ..       ...  ...              ...                ...   ...              ...
# 294        1    1           533886                NaN   120               70
# 295        2    1           527702              37.20    72               24
# 296        1    1           529386              37.50    72               30
# 297        1    1           530612              36.50   100               24
# 298        1    1           534618               37.2    40               20
#
# ...

# %%
sorted_horse_data = horse_data[['surgery?', 'age', 'rectal temperature', 'pulse', 'respiratory rate', 'temperature of extremities', 'pain', 
           'outcome']]
sorted_horse_data
# Out:
#     surgery?  age rectal temperature pulse respiratory rate  \
# 0          1    1               39.2    88               20
# 1          2    1              38.30    40               24
# 2          1    9              39.10   164               84
# 3          2    1              37.30   104               35
# 4          2    1                NaN   NaN              NaN
# ..       ...  ...                ...   ...              ...
# 294        1    1                NaN   120               70
# 295        2    1              37.20    72               24
# 296        1    1              37.50    72               30
# 297        1    1              36.50   100               24
# 298        1    1               37.2    40               20
#
#     temperature of extremities pain outcome
# 0                          NaN    3       3
# 1                            1    3       1
# 2                            4    2       2
# 3                          NaN  NaN       2
# ...

# %% [markdown]
# ### Задание 2. Первичное изучение данных
# Проанализировать значения по столбцам, рассчитать базовые статистики, найти выбросы.

# %%
sorted_horse_data.head(50)
# Out:
#    surgery?  age rectal temperature pulse respiratory rate  \
# 0         1    1               39.2    88               20
# 1         2    1              38.30    40               24
# 2         1    9              39.10   164               84
# 3         2    1              37.30   104               35
# 4         2    1                NaN   NaN              NaN
# 5         1    1              37.90    48               16
# 6         1    1                NaN    60              NaN
# 7         2    1                NaN    80               36
# 8         2    9              38.30    90              NaN
# 9         1    1              38.10    66               12
# 10        2    1              39.10    72               52
# 11        1    1              37.20    42               12
# 12        2    9              38.00    92               28
# 13        1    1               38.2    76               28
# 14        1    1              37.60    96               48
# ...

# %%
sorted_horse_data['age'].mean()
# Out:
# 1.6421404682274248

# %%
(sorted_horse_data.isna().mean()*100).round(2)
#(titanic.isna().mean() * 100).round(2)
# Out:
# surgery?                      0.0
# age                           0.0
# rectal temperature            0.0
# pulse                         0.0
# respiratory rate              0.0
# temperature of extremities    0.0
# pain                          0.0
# outcome                       0.0
# dtype: float64

# %%
sorted_horse_data.describe()
# Out:
#              age
# count  299.00000
# mean     1.64214
# std      2.17730
# min      1.00000
# 25%      1.00000
# 50%      1.00000
# 75%      1.00000
# max      9.00000

# %%
sorted_horse_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery?                    299 non-null    object
#  1   age                         299 non-null    int64
#  2   rectal temperature          299 non-null    object
#  3   pulse                       299 non-null    object
#  4   respiratory rate            299 non-null    object
#  5   temperature of extremities  299 non-null    object
#  6   pain                        299 non-null    object
#  7   outcome                     299 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 18.8+ KB

# %%
sorted_horse_data = sorted_horse_data.replace(to_replace='NaN', value='0')

# %%
#sorted_horse_data.astype('int64', errors='ignore').dtypes

# %%
sorted_horse_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery?                    299 non-null    object
#  1   age                         299 non-null    int64
#  2   rectal temperature          299 non-null    object
#  3   pulse                       299 non-null    object
#  4   respiratory rate            299 non-null    object
#  5   temperature of extremities  299 non-null    object
#  6   pain                        299 non-null    object
#  7   outcome                     299 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 18.8+ KB

# %%
sorted_horse_data['surgery?'].mean()
# Out:
# 4.054218131144185e+295

# %%
sorted_horse_data.describe()
# Out:
#              age
# count  299.00000
# mean     1.64214
# std      2.17730
# min      1.00000
# 25%      1.00000
# 50%      1.00000
# 75%      1.00000
# max      9.00000

# %%
sorted_horse_data['surgery?'].fillna(sorted_horse_data['surgery?'].mean(), inplace=True)
sorted_horse_data['surgery?'].fillna(sorted_horse_data['surgery?'].mean()).isna().sum()
# Out:
# 0

# %% [markdown]
# ### Значения для столбца "surgery?"

# %%
print('mean ', pd.to_numeric(sorted_horse_data['surgery?'], errors='coerce').mean())
print('median', pd.to_numeric(sorted_horse_data['surgery?'], errors='coerce').median())
print('mode', pd.to_numeric(sorted_horse_data['surgery?'], errors='coerce').mode()[0])
print('std', pd.to_numeric(sorted_horse_data['surgery?'], errors='coerce').std())
print('var', pd.to_numeric(sorted_horse_data['surgery?'], errors='coerce').var())
# Out:
# mean  1.391304347826087
# median 1.0
# mode 1
# std 0.495677257874841
# var 0.24569594397432162

# %%
def described(horses):
    for b in horses:
        print('mean ', b, pd.to_numeric(horses[b], errors='coerce').mean())
        print('median', b, pd.to_numeric(horses[b], errors='coerce').median())
        print('mode', b, pd.to_numeric(horses[b], errors='coerce').mode()[0])
        print('std', b, pd.to_numeric(horses[b], errors='coerce').std())
        print('var', b, pd.to_numeric(horses[b], errors='coerce').var())

# %%
described(sorted_horse_data)
# Out:
# mean  surgery? 1.391304347826087
# median surgery? 1.0
# mode surgery? 1
# std surgery? 0.495677257874841
# var surgery? 0.24569594397432162
# mean  age 1.6421404682274248
# median age 1.0
# mode age 1
# std age 2.1772997793587714
# var age 4.740634329195755
# mean  rectal temperature 30.50769230769233
# median rectal temperature 38.0
# mode rectal temperature 0.0
# std rectal temperature 15.325376190976206
# var rectal temperature 234.86715539494037
# mean  pulse 66.16053511705685
# median pulse 60.0
# mode pulse 48
# std pulse 33.75823510340228
# var pulse 1139.618437296582
# mean  respiratory rate 24.525083612040135
# median respiratory rate 22.0
# mode respiratory rate 0
# std respiratory rate 19.923221912773116
# var respiratory rate 396.9347713856028
# mean  temperature of extremities 1.9063545150501673
# median temperature of extremities 2.0
# mode temperature of extremities 3
# std temperature of extremities 1.3150878787863944
# ...

# %%
for b in sorted_horse_data:
    print('mean ', b, pd.to_numeric(sorted_horse_data[b], errors='coerce').mean())
    print('median', b, pd.to_numeric(sorted_horse_data[b], errors='coerce').median())
    print('mode', b, pd.to_numeric(sorted_horse_data[b], errors='coerce').mode()[0])
    print('std', b, pd.to_numeric(sorted_horse_data[b], errors='coerce').std())
    print('var', b, pd.to_numeric(sorted_horse_data[b], errors='coerce').var())
# Out:
# mean  surgery? 1.391304347826087
# median surgery? 1.0
# mode surgery? 1
# std surgery? 0.495677257874841
# var surgery? 0.24569594397432162
# mean  age 1.6421404682274248
# median age 1.0
# mode age 1
# std age 2.1772997793587714
# var age 4.740634329195755
# mean  rectal temperature 30.50769230769233
# median rectal temperature 38.0
# mode rectal temperature 0.0
# std rectal temperature 15.325376190976206
# var rectal temperature 234.86715539494037
# mean  pulse 66.16053511705685
# median pulse 60.0
# mode pulse 48
# std pulse 33.75823510340228
# var pulse 1139.618437296582
# mean  respiratory rate 24.525083612040135
# median respiratory rate 22.0
# mode respiratory rate 0
# std respiratory rate 19.923221912773116
# var respiratory rate 396.9347713856028
# mean  temperature of extremities 1.9063545150501673
# median temperature of extremities 2.0
# mode temperature of extremities 3
# std temperature of extremities 1.3150878787863944
# ...

# %% [markdown]
# ### Среднее для столбца "pulse"

# %%
pd.to_numeric(sorted_horse_data['pulse'], errors='coerce').mean()
# Out:
# 66.16053511705685

# %% [markdown]
# ### Среднее для столбца "rectal temperature"

# %%
pd.to_numeric(sorted_horse_data['rectal temperature'], errors='coerce').mean()
# Out:
# 30.50769230769233

# %% [markdown]
# ###  Среднее для остальных стлбцов

# %%
print('respiratory rate - ',pd.to_numeric(sorted_horse_data['respiratory rate'], errors='coerce').mean())
print('temperature of extremities - ', pd.to_numeric(sorted_horse_data['temperature of extremities'], errors='coerce').mean())
print('pain - ', pd.to_numeric(sorted_horse_data['pain'], errors='coerce').mean())
print('outcome - ', pd.to_numeric(sorted_horse_data['outcome'], errors='coerce').mean())
# Out:
# respiratory rate -  24.525083612040135
# temperature of extremities -  1.9063545150501673
# pain -  2.4013377926421406
# outcome -  1.5451505016722409

# %%
import numpy as np

# %%
sorted_h_d = sorted_horse_data.describe(include='all')
sorted_h_d = sorted_h_d.replace(to_replace='?', value='NaN')
sorted_h_d
# Out:
#        surgery?        age rectal temperature pulse respiratory rate  \
# count       299  299.00000                299   299              299
# unique        3        NaN                 66    53               41
# top           1        NaN                  0    48                0
# freq        180        NaN                 60    28               58
# mean        NaN    1.64214                NaN   NaN              NaN
# std         NaN    2.17730                NaN   NaN              NaN
# min         NaN    1.00000                NaN   NaN              NaN
# 25%         NaN    1.00000                NaN   NaN              NaN
# 50%         NaN    1.00000                NaN   NaN              NaN
# 75%         NaN    1.00000                NaN   NaN              NaN
# max         NaN    9.00000                NaN   NaN              NaN
#
#        temperature of extremities pain outcome
# count                         299  299     299
# ...

# %%
sorted_h_d.max()
# Out:
# age    299.0
# dtype: float64

# %% [markdown]
# ### Задание 3. Работа с пропусками
# Рассчитать количество пропусков для всех выбранных столбцов. Принять и обосновать решение о методе заполнения пропусков по каждому столбцу на основе рассчитанных статистик и возможной взаимосвязи значений в них. Сформировать датафрейм, в котором пропуски будут отсутствовать.

# %%
sorted_h_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, count to max
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery?                    4 non-null      object
#  1   age                         8 non-null      float64
#  2   rectal temperature          4 non-null      object
#  3   pulse                       4 non-null      object
#  4   respiratory rate            4 non-null      object
#  5   temperature of extremities  4 non-null      object
#  6   pain                        4 non-null      object
#  7   outcome                     4 non-null      object
# dtypes: float64(1), object(7)
# memory usage: 792.0+ bytes

# %% [markdown]
# ### Считаем пропуска в каждом столбце

# %%
print(sorted_h_d.isna().sum())
# Out:
# surgery?                      7
# age                           3
# rectal temperature            7
# pulse                         7
# respiratory rate              7
# temperature of extremities    7
# pain                          7
# outcome                       7
# dtype: int64

# %% [markdown]
# ###  Каждый столбец имеет 299 строк
# ### 7/299 = 2.3 %  Думаю можно просто удалить пустые строки

# %%
for b in sorted_h_d:
    print('mean ', b, round(pd.to_numeric(sorted_horse_data[b], errors='coerce').mean(), 4))
# Out:
# mean  surgery? 1.3913
# mean  age 1.6421
# mean  rectal temperature 30.5077
# mean  pulse 66.1605
# mean  respiratory rate 24.5251
# mean  temperature of extremities 1.9064
# mean  pain 2.4013
# mean  outcome 1.5452

# %%
sorted_h_d = sorted_h_d.dropna(axis=0, how='any')
sorted_h_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, count to count
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery?                    1 non-null      object
#  1   age                         1 non-null      float64
#  2   rectal temperature          1 non-null      object
#  3   pulse                       1 non-null      object
#  4   respiratory rate            1 non-null      object
#  5   temperature of extremities  1 non-null      object
#  6   pain                        1 non-null      object
#  7   outcome                     1 non-null      object
# dtypes: float64(1), object(7)
# memory usage: 72.0+ bytes

# %%
print(sorted_h_d.isna().sum())
# Out:
# surgery?                      0
# age                           0
# rectal temperature            0
# pulse                         0
# respiratory rate              0
# temperature of extremities    0
# pain                          0
# outcome                       0
# dtype: int64

# %%
for b in sorted_h_d:
    print('mean ', b, round(pd.to_numeric(sorted_horse_data[b], errors='coerce').mean(), 4))
# Out:
# mean  surgery? 1.3913
# mean  age 1.6421
# mean  rectal temperature 30.5077
# mean  pulse 66.1605
# mean  respiratory rate 24.5251
# mean  temperature of extremities 1.9064
# mean  pain 2.4013
# mean  outcome 1.5452

# %% [markdown]
# ### Комментарий
# До удаления пустых строк и после удаления средние значения остались одинаковыми, т.е. удаление строки с пустым значением в одной колонке не повлияло на соседние колонки
